# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Read the text from the file
with open("Emilee______14053804974_.txt", "r") as file:
    text = file.read()

# Generate the word cloud
wordcloud = WordCloud().generate(text)

# Display the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {"hadn't", 'where', 'other', 'was', 'hence', 'off', "it's", "hasn't", "wouldn't", 'its', "here's", 'our', 'could', 'herself', 'only', 'because', "don't", "who's", "she'll", 'very', "they'd", 'they', 'do', 'are', 'cannot', 'few', 'on', 'why', 'there', "mustn't", 'having', "where's", 'we', 'which', "i'll", 'themselves', 'after', 'you', 'r', 'then', 'theirs', 'during', "she'd", "what's", 'does', 'she', 'to', 'before', 'between', "he's", "she's", 'his', 'this', 'yours', 'com', 'each', 'into', 'like', 'www', 'also', 'me', 'if', 'who', 'be', 'her', "weren't", 'from', 'by', "there's", 'of', 'under', 'how', 'therefore', 'up', 'when', 'most', 'above', "he'd", 'over', "shan't", 'here', 'against', "you'd", 'had', "haven't", "how's", "i'm", 'that', 'or', 'an', 'once', 'did', 'it', 'both', 'ourselves', "they're", 'through', 'while', 'such', 'their', 'just', 'as', 'down', 'is', 'ever', 'has', 'however', 'myself', "that's", 'too', 'until', 'have', 'below', 'my', 'since', 'yourself', "didn't", 'what
# ...

# %%
stop_words = ["Emilee","Haha","tiktok"] + list(STOPWORDS)

# %%
STOPWORDS.update({"machine", "system"}) # add two words

# we specify new stopwords, max words as 60, width and height
wc = WordCloud(background_color="white",min_word_length=4,
        stopwords=stop_words, max_words=60, width=600, height=400
    ).generate(text)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
